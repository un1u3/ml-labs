# %%
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784',as_frame=False)

# %%
# tells about data 
x = mnist.DESCR

# %%
X = mnist.data
y = mnist.target

# %%
y.shape
# Out:
# (70000,)

# %%
y[0]
# Out:
# '5'

# %%
X_train, X_test, y_train, y_test = X[:6000], X[6000:], y[:6000], y[6000:]

# %%
y_test.shape
# Out:
# (64000,)

# %%
y_train_5 = (y_train == '5')
y_test_5 = (y_test == '5')
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
for i in range(10):
    print(sgd_clf.predict([X[i+12300]]))
# Out:
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [False]
# [ True]
# [False]

# %% [markdown]
# ### Performance Measure

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clf, X_train, y_train_5, cv=3, scoring="accuracy")
y_train_pred = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3)

# %%
from sklearn.dummy import  DummyClassifier
dummy_clf = DummyClassifier()

dummy_clf.fit(X_train,y_train_5)
# Out:
# DummyClassifier()

# %%
dummy_clf.predict(X_train)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
cross_val_score(dummy_clf,X_train,y_train_5,cv=3,scoring='accuracy')
# Out:
# array([0.914 , 0.9145, 0.9145])

# %% [markdown]
# ### Confusion Matrix
# The general idea of a confusion matrix is to count the number of times  <br>
# instance of class A are classified as Class B, for all A/B pairs <br>
# For example,to know the number of times the classifier confused images of 8s with 0s,<br>
# you would look at row #8, column #0 of the confusion matrix<br>

# %%
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_train_5,y_train_pred)

# %%
cm
# Out:
# array([[5375,  111],
#        [ 120,  394]])

# %%
from sklearn.metrics import f1_score
f1_score(y_train_5, y_train_pred)
# Out:
# 0.7733071638861629
