# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
import pandas as pd
import numpy as np

data = {
    'Size': [1400, 1600, 1700, 1875, 1100, 1550],
    'Bedrooms': [3, 4, 3, 5, 2, 3],
    'Age': [10, 15, 7, 2, 20, 13],
    'Price': [245000, 312000, 279000, 308000, 199000, 290000]
}
df = pd.DataFrame(data)

# make 15-row dataset by sampling existing rows + small noise
np.random.seed(42)

df15 = df.sample(n=15, replace=True).reset_index(drop=True)

df15["Size"] = (df15["Size"] + np.random.randint(-120, 121, size=15)).clip(800, 3500)
df15["Bedrooms"] = (df15["Bedrooms"] + np.random.randint(-1, 2, size=15)).clip(1, 7)
df15["Age"] = (df15["Age"] + np.random.randint(-3, 4, size=15)).clip(0, 60)
df15["Price"] = (df15["Price"] + np.random.randint(-25000, 25001, size=15)).clip(50000, 2000000)

df15
# Out:
#     Size  Bedrooms  Age   Price
# 0   1842         6    5  306483
# 1   1215         3   21  222555
# 2   1737         4    4  271159
# 3   1017         2   23  218974
# 4   1109         3   18  214994
# 5   1671         4   15  301541
# 6   1767         3    4  289920
# 7   1600         4    7  280531
# 8   1740         3    9  255585
# 9   1183         3   18  177943
# 10  1812         6    0  306939
# 11  1601         2    4  273457
# 12  1665         4   11  266021
# 13  1068         1   21  185653
# 14  1528         5   13  330573

# %%
# lr from scratch 
m =0 
c = 0 
lr = 0.0001
epoch = 100 
n = len(X)
n
# Out:
# 100

# %%
class LinearModel:
    def __init__(self,lr,epoch):
        self.lr = lr 
        self.theta = None
        self.epoch = epoch
        

    def fit(self,X,y):
        self.theta = np.zeros((2,1))
        for i in range(epoch):
            y_pred = X @ self.theta
            error = y_pred - y 
            cost = (1/(2*n))*np.sum(error **2)
            d_theta = (1/n)*(X.T @ error)
            self.theta = self.theta - lr * d_theta
        
    def predict(self,X):
        return X @ self.theta

# %%
model = LinearModel(0.0001,1000)
model

# %%
model.fit(X,y)
model.predict(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3877374192.py in <cell line: 0>()
#       1 model.fit(X,y)
# ----> 2 model.predict(y)
#
# /tmp/ipython-input-735346442.py in predict(self, X)
#      16
#      17     def predict(self,X):
# ---> 18         return X @ self.theta
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
